# %%
# DataBase connection in python

# %%
import pandas as pd
import pyodbc

# %%
SERVER_NAME = '000.30.63.139' # IP address
DATABASE_NAME = 'DBName'  #DatabaseName
username = 'sa' #UserName
password = 'abc@1234'  # Password
# Sql server connectionn when inline input
#sql_conn = pyodbc.connect('DRIVER={SQL Server};SERVER=000.30.63.139;DATABASE=DB_Dev;UID=sa;PWD=abc@1234')
# below Sql server connectionn when declared variable used for connection
sql_conn = pyodbc.connect('DRIVER={SQL Server};SERVER='+ SERVER_NAME +';DATABASE=' + DATABASE_NAME + ';UID=' +username+';PWD='+password)
cursor = sql_conn.cursor()

# %%
query = 'SELECT * FROM TableName;'
df = pd.read_sql( query, sql_conn )
df.head()
# Out:
#    ID RequestType              BankAbbr BranchCode               BankName  \
# 0   1         New                   CBL       MS01  Co-operative Bank Ltd
# 1  11      Delete                   ABC       1111              Test Bank
# 2   3      Delete                   CBL       MS01  Co-operative Bank Ltd
# 3   4         New                   ABC       1111              Test Bank
# 4   5         New  Bank Abbr Final Test         BC              Bank Name
#
#         BIC           BankFullName   BankAddress  BankCodeLength   BranchName  \
# 0  CPOBMMMY  Co-operative Bank Ltd        Yangon               4         Deli
# 1    ABCDEF              Test Bank          None               4  Test Branch
# 2  CPOBMMMY  Co-operative Bank Ltd        Yangon               4         Deli
# 3    ABCDEF              Test Bank          None               4  Test Branch
# 4       BIC              Bank Name  Bank Address               2  Branch Name
#
# ...
